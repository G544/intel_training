# %%
def equit(a,b,c, x):
    if (a*x + b)**0.5 == float(c):
        return x
    else:
        return 'slu'
    
def trying(a,b,c):
    x = 'slu'
    flag = False
    for i in range(-10000, 10000):
        x_t = equit(a,b,c, i)
    
        if x_t != 'slu':
            flag = True
            if x != 'slu':
                return 'MANY SOLUTIONs'
            else:
                x = x_t
  
    if flag:
        return x
    else:
        return 'NO SOLUTION'
        
        
a = int(input())
b = int(input())
c = int(input())

print(trying(a,b,c))
# Out:
# 0
# 0
# 0
# MANY SOLUTIONs

# %%
#a = int(input())
#b = int(input())
#c = int(input())

def my_func(a,b,c):
    if (c < 0): 
        return('NO SOLUTION')
    elif (a == 0):
        if b == c**2:
            return('MANY SOLUTIONS')
        else:
             return('NO SOLUTION')

    else:
        x = (c**2-b)/a
        if (a*x +b) < 0:
            return('NO SOLUTION')
        else:
            if (c**2-b)%a != 0:
                return('NO SOLUTION')
            else:
                return(int(x))

# %%
from random import randint
while True:
    a,b,c = [randint(1,10), randint(1,10), randint(1,10)]
    x1 = my_func(a,b,c)
    x2 = trying(a,b,c )
    if x1 != x2:
        print( x1)
        print(x2)
        print(a,b,c)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16760/2062724299.py in <module>
#       3     a,b,c = [randint(1,10), randint(1,10), randint(1,10)]
#       4     x1 = my_func(a,b,c)
# ----> 5     x2 = trying(a,b,c )
#       6     if x1 != x2:
#       7         print( x1)
#
# ~\AppData\Local\Temp/ipykernel_16760/760191217.py in trying(a, b, c)
#       9     flag = False
#      10     for i in range(-10000, 10000):
# ---> 11         x_t = equit(a,b,c, i)
#      12
#      13         if x_t != 'slu':
#
# ~\AppData\Local\Temp/ipykernel_16760/760191217.py in equit(a, b, c, x)
#       1 def equit(a,b,c, x):
# ----> 2     if (a*x + b)**0.5 == float(c):
#       3         return x
#       4     else:
#       5         return 'slu'
#
# KeyboardInterrupt:

# %% [markdown]
# # Задача I

# %%
        
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())

k =  max(a,b,c)
a1, b1 = [a,b,c].remove(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16760/612626755.py in <module>
# ----> 1 a = int(input())
#       2 b = int(input())
#       3 c = int(input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())

def func(a,b,c,d,e):
    k =  max(a,b,c)
    a = [a,b,c]
    a.remove(k)
    a1 = max(a)
    b1 = min(a)
    d1 = max(d,e)
    c1 = min(d,e)


    if a1<c1:
        return 'YES'
    elif a1>d1:
        return 'NO'
    elif b1 > c1:
        return 'NO'
    else:
        return 'YES'
    
print(func(a,b,c,d,e))
# Out:
# 3
# 6
# 8
# 9
# 2
# 6
# 9
# NO

# %%
        
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())


func(a,b,c,d,e)
# Out:
# 1
# 5
# 6
# 3
# 4
# 'YES'

# %%
a.remove(8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16760/2375756575.py in <module>
# ----> 1 a.remove(8)
#
# ValueError: list.remove(x): x not in list

# %%
a1
# Out:
# 1

# %%
b1
# Out:
# 4
