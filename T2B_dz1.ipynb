# %% [markdown]
# # Задачка 1

# %%
N, a, b = [int(s) for s in input().split(' ')]

a1 = max(a,b)
b1 = min(a,b)

var1 = a1 - b1 -1
var2 = N + b1 - a1 -1
print(min(var1, var2))
# Out:
# 10 1 9
# 1

# %%
0 and 0
# Out:
# 0

# %% [markdown]
# # Задачка 2

# %%
x, y, z = [int(s) for s in input().split(' ')]

def check_eu(x,y,z):
    if y < 12:
        return 1
    else:
        return 0
    
def check_us(x,y,z):
    if x < 12:
        return 1
    else:
        return 0
    
def check_date(x,y,z):
    if x==y:
            return 1

    a =  check_eu(x,y,z)
    b =  check_us(x,y,z)
    if a and b:
        return 0
    else:
        return 1
    
print(check_date(x,y,z))
# Out:
# 9 9 2027
# 1

# %% [markdown]
# # Задача 3

# %%
i = int(input())
a =  [int(s) for s in input().split(' ')]

b = a[len(a)//2]
print(b)
# Out:
# 3
# -1 0 1

# %% [markdown]
# # Задача 4

# %%
d = int(input())
x1, y1 =[int(s) for s in input().split(' ')]

if (y1 <= d-x1) and (y1 <= d and y1>=0) and (x1 <= d and x1>=0):
    b = 0
else:
    a = normal(x1,y1, 0,0)
    b = normal(x1,y1, d,0)
    c = normal(x1,y1, 0,d)
    mini = a
    num = 1
    i = 0
    for item in ([b,c]):
        if item<mini:
            mini = item
            num = i+2
        i+=1
    b= num
    
def normal(x1,y1,x2,y2):
    return ((x2-x1)**2+(y2-y1)**2)

print(b)
# Out:
# 3
# -1 -1
# 1
